# %%
import pandas as pd
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %% [markdown]
# # EJERCICIO 1, 2 & 3:

# %% [markdown]
# ### loading first set of Graphics / Tiles inside Dashboard

# %%
image1 = mpimg.imread(r'C:\Users\tomi_\Documents\Cibernarium\Ejercicios_Python\S19\Kibana dashboard.jpg')

# %%
plt.figure(figsize = (200,200))
plt.imshow(image1, interpolation='nearest')

# %% [markdown]
# I've built four initial graphics/tiles:
#
# - Bar chart visualizing AirTime and DelayTime by Carrier. Only top 5 are displayed while rest is grouped.
# - Pie chart visualizing amount of flights distributed by Weekday
# - Treemap visualizing count of flights by Destination. 22% of Other flights are grouped together.
# - Line chart visualizing proportion % ArrDelay vs Elapsed Arrival Time by Carrier.

# %% [markdown]
# ### Interaction of dashboard: display of graphics after having selected one of the possible FullCarrier values

# %%
image2 = mpimg.imread(r'C:\Users\tomi_\Documents\Cibernarium\Ejercicios_Python\S19\Kibana dashboard - filtered.jpg')

# %%
plt.figure(figsize = (200,200))
plt.imshow(image2, interpolation='nearest')

# %% [markdown]
# After selecting the first Carrier displayed in Graph 1, it's being applied as filter in every existing chart resulting in different set of values.
#
# For example it is visible that for this Carrier there are no flights recorded on Weekday 6 (Saturday).
# Also, its quite visible that for Charts 1 and 4 there's only one variable.

# %% [markdown]
# ### Two additional tiles to complete every possible type of graphic

# %%
image3 = mpimg.imread(r'C:\Users\tomi_\Documents\Cibernarium\Ejercicios_Python\S19\Kibana - added tiles.jpg')

# %%
plt.figure(figsize = (500,50))
plt.imshow(image3)

# %% [markdown]
# Two final charts have been added to the dashboard:
#     - Table exposing main KPI's by carrier (AverageSpeed, Average AirTime, Average DepDelay, Average ArrDelay)
#     - Stacked bar chart visualizing percentage of flights by day and by carrier.
